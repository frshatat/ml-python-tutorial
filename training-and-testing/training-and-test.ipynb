# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["Mileage"], df["Sell Price($)"])

# %%
plt.scatter(df["Age(yrs)"], df["Sell Price($)"])

# %%
x = df[["Mileage", "Age(yrs)"]]
y = df["Sell Price($)"]

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(x_train)
x_train
# Out:
#     Mileage  Age(yrs)
# 2     57000         5
# 15    25400         3
# 16    28000         2
# 0     69000         6
# 11    79000         7
# 14    82450         7
# 6     52000         5
# 17    69000         5
# 19    52000         5
# 7     72000         6
# 10    83000         7
# 4     46000         4
# 8     91000         8
# 13    58780         4
# 9     67000         6
# 1     35000         3

# %%
len(x_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([25391.50163204, 15407.10468601, 38181.7494296 , 25391.50163204])

# %%
y_test
# Out:
# 5     26750
# 18    12800
# 3     40000
# 12    26000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.9667240527613215
